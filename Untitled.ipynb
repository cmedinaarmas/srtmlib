# %%
import block as bl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
# data = 'data/everest/n27_e086_1arc_v3.bil'
data = 'data/guadaloupe/n15_w062_3arc_v2.bil'
b = bl.Block(data,3,0)
b.load_data(wrapped=False)
h = b.heights
print(b.src_file)
print(h.shape)
# Out:
# data/guadaloupe/n15_w062_3arc_v2.bil
# (1201, 1201)

# %%
print(h.max())
h_clip=np.clip(h,0,1000)
print(h_clip.max())
# Out:
# 65535
# 1000

# %%
fig=plt.figure(figsize=(10,10))
plt.imshow(h_clip,cmap='gray')
plt.show()
